# %%
import pandas as pd
import numpy as np
import collections

# %%
url = 'https://raw.githubusercontent.com/mattharrison/datasets/master/data/2020-jetbrains-python-survey.csv'
df = pd.read_csv(url)
df.head()
# Out:
# /home/hossein/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (152) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   is.python.main other.lang.None other.lang.Java other.lang.JavaScript  \
# 0            Yes             NaN             NaN                   NaN
# 1            Yes             NaN            Java            JavaScript
# 2            Yes             NaN             NaN                   NaN
# 3            Yes             NaN             NaN            JavaScript
# 4            Yes             NaN            Java            JavaScript
#
#   other.lang.C/C++ other.lang.PHP other.lang.C# other.lang.Ruby  \
# 0              NaN            NaN           NaN             NaN
# 1              NaN            NaN            C#             NaN
# 2            C/C++            NaN           NaN             NaN
# ...

# %%
for c in sorted(df.columns):
    print(c,'-->', df[c].dtype)
# Out:
# age --> object
# are.you.datascientist --> object
# bigdata.Apache Beam --> object
# bigdata.Apache Flink --> object
# bigdata.Apache Hadoop/MapReduce --> object
# bigdata.Apache Hive --> object
# bigdata.Apache Kafka --> object
# bigdata.Apache Samza --> object
# bigdata.Apache Spark --> object
# bigdata.Apache Tez --> object
# bigdata.ClickHouse --> object
# bigdata.Dask --> object
# bigdata.None --> object
# bigdata.Other --> object
# ci.AppVeyor --> object
# ci.Bamboo --> object
# ci.CircleCI --> object
# ci.CruiseControl --> object
# ci.Gitlab CI --> object
# ci.Jenkins / Hudson --> object
# ci.None --> object
# ci.Other --> object
# ci.TeamCity --> object
# ci.Travis CI --> object
# cloud.platform.AWS --> object
# cloud.platform.DigitalOcean --> object
# cloud.platform.Google Cloud Platform --> object
# cloud.platform.Heroku --> object
# cloud.platform.Linode --> object
# cloud.platform.Microsoft Azure --> object
# cloud.platform.None --> object
# ...

# %%
countr = collections.defaultdict(list)
for col in sorted(df.columns):
    period_count = col.count('.')
    if period_count >= 2 :
        part_end = 2
    else:
        part_end = 1
    parts = col.split('.')[:part_end]
    countr['.'.join(parts)].append(col)
# print(countr)

# %%
uniq_cols = []
for k,v in countr.items():
    if len(v) == 1:
        uniq_cols.append(v[0])
uniq_cols
# Out:
# ['age',
#  'are.you.datascientist',
#  'company.size',
#  'country.live',
#  'employment.status',
#  'first.learn.about.main.ide',
#  'how.often.use.main.ide',
#  'ide.main',
#  'is.python.main',
#  'job.team',
#  'main.purposes',
#  'missing.features.main.ide',
#  'nps.main.ide',
#  'python.years',
#  'python2.version.most',
#  'python3.version.most',
#  'several.projects',
#  'team.size',
#  'use.python.most',
#  'years.of.coding']

# %%
(df
[uniq_cols]
.rename(columns = lambda c:c.replace('.','_'))
.age
.value_counts(dropna=False)
)
# Out:
# NaN            29701
# 21–29           9710
# 30–39           7512
# 40–49           3010
# 18–20           2567
# 50–59           1374
# 60 or older      588
# Name: age, dtype: int64

# %%
(df
[uniq_cols]
.rename(columns = lambda c:c.replace('.','_'))
# .age
# .str.slice(0,2)
# .astype(float)
# .astype('Int64')
.are_you_datascientist
.value_counts(dropna=False)
)
# Out:
# NaN      33198
# No       13399
# Yes       6710
# Other     1155
# Name: are_you_datascientist, dtype: int64

# %%
(df
[uniq_cols]
.rename(columns = lambda c:c.replace('.','_'))
.assign(age = lambda df_:df_.age.str.slice(0,2).astype(float).astype('Int64')
,are_you_datascientist = lambda df_:df_.are_you_datascientist.replace({'Yes':True,'No':False}))
.are_you_datascientist
.value_counts(dropna=False)
)
# Out:
# NaN      33198
# False    13399
# True      6710
# Other     1155
# Name: are_you_datascientist, dtype: int64

# %%
(df
[uniq_cols]
.rename(columns = lambda c:c.replace('.','_'))
.assign(age = lambda df_:df_.age.str.slice(0,2).astype(float).astype('Int64')
,are_you_datascientist = lambda df_:df_.are_you_datascientist.replace({'Yes':True,'No':False}))
.company_size
.value_counts(dropna=False)
)
# Out:
# NaN                35037
# 51–500              4608
# More than 5,000     3635
# 11–50               3507
# 2–10                2558
# 1,001–5,000         1934
# Just me             1492
# 501–1,000           1165
# Not sure             526
# Name: company_size, dtype: int64

# %%
city_bike_df = pd.read_csv('201306-citibike-tripdata.csv')
city_bike_df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
city_bike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
(city_bike_df
.rename(columns = lambda c:c.replace(' ','_'))
.assign(starttime = lambda df_:pd.to_datetime(df_.starttime)
,stoptime = lambda df_:pd.to_datetime(df_.stoptime)
,start_station_id =lambda df_: df_.start_station_id.astype('category')
,usertype =lambda df_: df_.usertype.astype('category')
)
).memory_usage()
# Out:
# Index                          128
# tripduration               4621624
# starttime                  4621624
# stoptime                   4621624
# start_station_id           1166398
# start_station_name         4621624
# start_station_latitude     4621624
# start_station_longitude    4621624
# end_station_id             4621624
# end_station_name           4621624
# end_station_latitude       4621624
# end_station_longitude      4621624
# bikeid                     4621624
# usertype                    577827
# birth_year                 4621624
# gender                     4621624
# dtype: int64

# %%
city_bike_df.memory_usage()
# Out:
# Index                          128
# tripduration               4621624
# starttime                  4621624
# stoptime                   4621624
# start station id           4621624
# start station name         4621624
# start station latitude     4621624
# start station longitude    4621624
# end station id             4621624
# end station name           4621624
# end station latitude       4621624
# end station longitude      4621624
# bikeid                     4621624
# usertype                   4621624
# birth year                 4621624
# gender                     4621624
# dtype: int64

# %%
def tweak_courses(df):
    return(
        df.
        assign(




    )
# Out:
# Index(['Unnamed: 0', 'title', 'hours', 'videos', 'exercises', 'participants',
#        'xp', 'clean', 'descriptions', 'tracks', 'instructors', 'datasets',
#        'prereqs', 'link', 'topic', 'tech'],
#       dtype='object')

# %%
#1. Find out which columns have missing data
city_bike_df.isna().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id              True
# end station name            True
# end station latitude        True
# end station longitude       True
# bikeid                     False
# usertype                   False
# birth year                  True
# gender                     False
# dtype: bool

# %%
#2. Count the number of missing values for each column.
city_bike_df.isna().sum()
# Out:
# tripduration                    0
# starttime                       0
# stoptime                        0
# start station id                0
# start station name              0
# start station latitude          0
# start station longitude         0
# end station id              18059
# end station name            18059
# end station latitude        18059
# end station longitude       18059
# bikeid                          0
# usertype                        0
# birth year                 240321
# gender                          0
# dtype: int64

# %%
#Find the percentage of missing values for each column
city_bike_df.isna().sum() * 100 /city_bike_df.shape[0]
# Out:
# tripduration                0.000000
# starttime                   0.000000
# stoptime                    0.000000
# start station id            0.000000
# start station name          0.000000
# start station latitude      0.000000
# start station longitude     0.000000
# end station id              3.126001
# end station name            3.126001
# end station latitude        3.126001
# end station longitude       3.126001
# bikeid                      0.000000
# usertype                    0.000000
# birth year                 41.599403
# gender                      0.000000
# dtype: float64

# %%
#4. Find the rows with missing data.
city_bike_df.isna().any(axis=1)
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 577698    False
# 577699     True
# 577700    False
# 577701     True
# 577702     True
# Length: 577703, dtype: bool

# %%
#5. Find the rows that are duplicated
(city_bike_df
.assign(is_duplicated = lambda df_:df_ == df_.shift(1))
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_duplicated'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
city_bike_df.dup.any()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_394589/1382574581.py in <module>
# ----> 1 city_bike_df.is_duplicated.any()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'is_duplicated'
