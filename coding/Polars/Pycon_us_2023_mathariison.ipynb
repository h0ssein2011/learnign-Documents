# %%
import pandas as pd
import polars as pl

# %%
pl.__version__
# Out:
# '1.7.0'

# %%
url = 'https://raw.githubusercontent.com/mattharrison/2023-Pycon-Polars/main/__mharrison__2020-2021.csv'
df = pl.read_csv(url)
df
# Out:
# shape: (5_791, 40)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Tweet id  ┆ Tweet     ┆ Tweet     ┆ time      ┆ … ┆ promoted  ┆ promoted  ┆ promoted  ┆ promoted │
# │ ---       ┆ permalink ┆ text      ┆ ---       ┆   ┆ email     ┆ dial      ┆ media     ┆ media    │
# │ i64       ┆ ---       ┆ ---       ┆ str       ┆   ┆ tweet     ┆ phone     ┆ views     ┆ engageme │
# │           ┆ str       ┆ str       ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ nts      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 121258051 ┆ https://t ┆ Sounds    ┆ 2020-01-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# ...

# %%
print(len(dir(pl)))
# Out:
# 200

# %%
df.sample(20).transpose()
# Out:
# shape: (40, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ column_0  ┆ column_1  ┆ column_2  ┆ column_3  ┆ … ┆ column_16 ┆ column_17 ┆ column_18 ┆ column_1 │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ 9        │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 137330697 ┆ 133474261 ┆ 145954590 ┆ 146857251 ┆ … ┆ 129101387 ┆ 134632483 ┆ 128350651 ┆ 14383573 │
# │ 479687372 ┆ 167691777 ┆ 112332595 ┆ 502688666 ┆   ┆ 456553779 ┆ 693138739 ┆ 637749760 ┆ 09613248 │
# │ 9         ┆ 0         ┆ 5         ┆ 8         ┆   ┆ 2         ┆ 4         ┆ 1         ┆ 519      │
# ...

# %%
df.dtypes
# Out:
# [Int64,
#  String,
#  String,
#  String,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Float64,
#  Int64,
#  Int64,
#  Int64,
#  Int64,
#  Int64,
#  Int64,
#  Int64,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String,
#  String]
